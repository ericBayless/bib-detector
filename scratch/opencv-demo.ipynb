# %%
import os

import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
cv2.data.haarcascades
# Out:
# '/Users/ebay/opt/anaconda3/envs/bib-reader/lib/python3.8/site-packages/cv2/data/'

# %%
# Load classifier
clf = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Load image in grayscale mode
img = cv2.imread('./Data/RBNR/set1_org/set1_24.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img)

# %%
# Run detection and check results
boxes = clf.detectMultiScale(gray, 1.3, 5)

boxes
# Out:
# array([[143,  63,  58,  58]], dtype=int32)

# %%
for (x,y,w,h) in boxes:
    img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]

# From Documentation - Opens separate window and hangs
# cv2.imshow('img',img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# Display using matplotlib
plt.imshow(img)

# %%
cv2.imshow()

# %% [markdown]
# ## Next Steps
# Run through all images and see how many have no detections to determine if this will be useable.
